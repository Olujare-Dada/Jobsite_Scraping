# %%
#from dotenv import load_dotenv
import os
from datetime import datetime
from dotenv import load_dotenv

# %%
curr_time = datetime.now()
datetime_val = curr_time.strftime("%Y-%m-%d %H:%M:%S")

# %%
#load_dotenv("azure_client_credentials.env")

# %%
load_dotenv("azure_client_credentials.env")

# Access the environment variables
azure_client_id = os.environ["AZURE_CLIENT_ID"]
azure_tenant_id = os.environ["AZURE_TENANT_ID"]
azure_client_secret = os.environ["AZURE_CLIENT_SECRET"]
storage_account_name = "jobbermanstoragefiles"

# %% [markdown]
# #### log_data_to_db:

# %%
server = 'vinserve.database.windows.net'
database = 'Vin'
username = 'Vincent'
password = 'Nimrod007'
driver = '{ODBC Driver 17 for SQL Server}'
database_table_name = '[dbo].[Final_template_df]'

# %%
# %store server
# %store database
# %store username
# %store password
# %store driver
# %store storage_account_name
# %store database_table_name
# Out:
# Stored 'server' (str)
# Stored 'database' (str)
# Stored 'username' (str)
# Stored 'password' (str)
# Stored 'driver' (str)
# Stored 'storage_account_name' (str)
# Stored 'database_table_name' (str)

# %% [markdown]
# #### Data_Cleaning_and_Transformation:

# %%
load_dotenv("exchange_rate_api_key.env")
exchange_rate_api_url = os.environ["EXCHANGE_RATE_API_KEY"]#'https://v6.exchangerate-api.com/v6/f1832750ec5f421a14e74fe8/latest/USD'


load_dotenv("openai_key.env")
openai_key = os.environ["OPENAI_KEY"]#"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"

azure_container_name = ["rawscrapeddata", "cleaneddata"]
#sas_connection_string = "https://jobbermanstoragefiles.blob.core.windows.net/rawscrapeddata?sp=ral&st=2023-10-19T10:52:02Z&se=2023-12-01T18:52:02Z&spr=https&sv=2022-11-02&sr=c&sig=LeiFbTxj1WaLZMTe1LXBK2yCk%2Fi8BP5UVsaUzQEz6xA%3D"

# %%
# %store exchange_rate_api_url
# %store openai_key
# %store azure_container_name
#%store sas_connection_string
# Out:
# Stored 'exchange_rate_api_url' (str)
# Stored 'openai_key' (str)
# Stored 'azure_container_name' (list)

# %% [markdown]
# ### File Orchestration

# %%
try:
    # %run "./Scraping_Jobberman.py"
    
    
except Exception as e:
    print(e)
    

else:
    print("Scraping complete!")
# Out:
# <!DOCTYPE html>
#
# <html class="no-js scroll-smooth" lang="en-ng">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="4hClu3W3PtjepabInbxYOahjMMOlzUNqWBY9OKZJtdA" name="google-site-verification">
# <meta content="gcNPeUNb50ypQc79OWfk2YQRxsJ9EkuNWMb8hxBl" name="csrf-token"/>
# <link href="https://www.jobberman.com/listings/backend-developer-evdg2j" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/graphics-designer-20zp5g" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/accountant-jqmvxe" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/business-development-associate-xpd4kn" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/financial-reporting-assistant-wpmqkk" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/customer-service-officer-9j04n5" rel="prerender"/>
# ...

# %%
try:
    # %run "./Data_Cleaning_and_Transformation.ipynb"
    
    
except Exception as e:
    print(e)
    
    
else:
    print("Data cleaning pipeline ran successfully!")
# Out:
# Raw parquet file created! The raw CSV file will be deleted at the end of this process
# 0
# Cleaning and Transforming in chunks of 20
# Finished step 1: Checking recorded column names
# Finished step 2: Removing newline characters
# No bracket locations with Rest of Nigeria
# Location value = Lagos
# No bracket locations with Rest of Nigeria
# Location value = Lagos
# No bracket locations with Rest of Nigeria
# Location value = Lagos
# No bracket locations with Rest of Nigeria
# Location value = Lagos
# No bracket locations with Rest of Nigeria
# Location value = Lagos
# No bracket locations with Rest of Nigeria
# Location value = Lagos
# No bracket locations with Rest of Nigeria
# Location value = Lagos
# No bracket locations with Rest of Nigeria
# Location value = Lagos
# No bracket locations with Rest of Nigeria
# Location value = Lagos
# No bracket locations with Rest of Nigeria
# Location value = Lagos
# No bracket locations with Rest of Nigeria
# Location value = Lagos
# ...

# %%
try:
    # %run "./Log_data_to_db.ipynb"
    #print("Data has been logged successfully on the Azure db")
    
except Exception as e:
    print(e)
    
    
else:
    print("Data has been logged successfully on the Azure db")
# Out:
# Encountered an error.
# Python error: Unknown datetime string format, unable to parse: Scrape_Time, at position 20
# Index([20, 41, 62, 83, 104, 125, 146, 167], dtype='int64')
# 8 rows dropped because they are recorded column names
# Connection attempt 1 failed: ('08001', '[08001] [Microsoft][ODBC Driver 17 for SQL Server]TCP Provider: Timeout error [258].  (258) (SQLDriverConnect); [08001] [Microsoft][ODBC Driver 17 for SQL Server]Login timeout expired (0); [08001] [Microsoft][ODBC Driver 17 for SQL Server]Unable to complete login process due to delay in login response (258)')
# Connection established
# Row 0 inserted successfully
# Row 1 inserted successfully
# Row 2 inserted successfully
# Row 3 inserted successfully
# Row 4 inserted successfully
# Row 5 inserted successfully
# Row 6 inserted successfully
# Row 7 inserted successfully
# Row 8 inserted successfully
# Row 9 inserted successfully
# Row 10 inserted successfully
# Row 11 inserted successfully
# ...

# %%
try:
    # %run "./Data Cleanup and backup.ipynb""
    #print("Data has been logged successfully on the Azure db")
    
except Exception as e:
    print(e)
    
    
else: 
    print("Data has been logged successfully on the Azure blob storage and cleaned from environment")
# Out:
# File 'Jobberman_data_raw.csv' has been deleted.
# Number of tries: 1
# File 'Completed_Cleaned_Jobberman.csv' has been deleted.
# Data has been logged successfully on the Azure blob storage and cleaned from environment
